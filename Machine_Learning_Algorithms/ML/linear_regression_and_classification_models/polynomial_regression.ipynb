# %% [markdown]
# # Polynomial Regression Algorithm

# %% [markdown]
# ### Importing Libraries

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_circles
from matplotlib import pyplot as plt

# %% [markdown]
# ### Generating circular data

# %%
X, y = make_circles(n_samples=1000, noise=.04)

# %% [markdown]
# ### Plotting data

# %%
plt.scatter(X[:, 0], X[:, 1], c=y, s=10)

# %% [markdown]
# ### fitting data

# %%
pol = PolynomialFeatures(degree=2)
X_tf = pol.fit_transform(X)
lr = LogisticRegression()
trainX, testX, trainY, testY = train_test_split(X_tf, y)
lr.fit(trainX, trainY)
# Out:
# LogisticRegression()

# %%
print(lr.score(testX, testY))
print(lr.coef_)
# Out:
# 0.988
# [[ 1.21621043e-05  6.61752805e-03 -5.93980481e-02 -9.37633474e+00
#    1.76228898e-01 -9.27566226e+00]]
